# %% [markdown]
# # TASKS

# %% [markdown]
# 1. Investigate the following variables (Plot histograms and describe properties for each channel (Lpmunu,Lppi, DIF)):
#
#     i)    Lambda0_QPT (search Armenteros-Podolanski info, and google images to understand it)
#
#     ii)   Lambda0_BPVCORRM
#
#     iii)  Lambda0_FD_OWNPV  (Flight Distance of the Lambda0
#
#     iv)   VeloMatterVeto
#
#     v)    mu_ProbNNmu
#
#     vi)   Mppi
#
#     vii)  MppiCorr
#
#     viii) Mpi2

# %% [markdown]
# 2. With the info of previous task, try to design some selection cuts to separate signal and background.
